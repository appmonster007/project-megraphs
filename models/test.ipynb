# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
# from sklearn. import 
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_excel('labeled_real_webedu.xlsx')
df_y = df['Betweeness Centrality']
df_inp = df.drop(['Betweeness Centrality','Node'],axis=1)

# %%
TEST_SHARE = 0.95
Train_Input, Test_Input, Train_Label, Test_Label = train_test_split(df_inp,df_y,test_size=TEST_SHARE)

model = RandomForestRegressor()
# model =

# %%
model.fit(Train_Input,Train_Label)
# Out:
# RandomForestRegressor()

# %%
prediction_labels = model.predict(Test_Input)
compare_df = pd.DataFrame({'actual':Test_Label,'predict':prediction_labels})

# %%
# plt.scatter(list(compare_df.index.to_numpy()),list(compare_df['actual'].to_numpy()))
# plt.scatter(list(compare_df.index.to_numpy()),list(compare_df['predict'].to_numpy()))
# print(compare_df.index.to_numpy().size,compare_df['actual'].to_numpy().size)
# plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 6))
x = list(compare_df.index.to_numpy())
actual = list(compare_df['actual'].to_numpy())
predict = list(compare_df['predict'].to_numpy())

ax.scatter(x,actual,color='blue')
ax.scatter(x,predict,color='orange')

# ax.set_ylim([0,0.3])
plt.show()

# %%
print(model.score(Test_Input,Test_Label),model.score(Train_Input,Train_Label))
# Out:
# 0.14676548001292367 0.9203149591740376

# %%
print(compare_df.to_string())
# Out:
#             actual       predict
# 2871  0.000000e+00  4.611843e-04
# 1202  1.089577e-07  1.089577e-07
# 759   1.089577e-07  1.089577e-07
# 263   0.000000e+00  3.732958e-04
# 1280  1.089577e-07  1.089577e-07
# 1989  1.089577e-07  1.089577e-07
# 2785  1.319914e-03  7.655992e-04
# 1789  1.089577e-07  1.089577e-07
# 1287  1.089577e-07  1.089577e-07
# 1062  1.089577e-07  1.089577e-07
# 796   1.089577e-07  1.089577e-07
# 2551  1.089577e-07  1.089577e-07
# 2058  3.336962e-02  2.396536e-02
# 342   6.600660e-04  1.307655e-03
# 2281  1.089577e-07  1.089577e-07
# 2418  1.089577e-07  1.089577e-07
# 2133  1.089577e-07  1.089577e-07
# 1637  1.089577e-07  1.089577e-07
# 639   1.089577e-07  1.089577e-07
# 1382  1.089577e-07  1.089577e-07
# 2295  1.089577e-07  1.089577e-07
# 450   1.089577e-07  1.089577e-07
# 2353  1.089577e-07  1.089577e-07
# 855   1.089577e-07  1.089577e-07
# 464   1.089577e-07  1.089577e-07
# 3024  2.155206e-02  9.314765e-04
# 1733  0.000000e+00  0.000000e+00
# ...
